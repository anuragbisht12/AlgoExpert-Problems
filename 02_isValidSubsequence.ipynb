# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#validate whether a given sequence  is valid subsequence of an array

# %%
def isValidSubsequence(array, sequence):
    index=0
	for val in array:
		if index==len(sequence):
			break
		if sequence[index]==val:
			index+=1
	return index == len(sequence)
